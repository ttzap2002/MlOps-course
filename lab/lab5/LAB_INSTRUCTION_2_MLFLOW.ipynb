# %% [markdown]
# # Laboratory 5 instruction part 2 - MLflow
#
# In machine learning development, one of the most challenging aspects is maintaining reproducibility. This issue is particularly relevant to the experimental phase, when a lot of small, but influential code changes are constantly introduced.
#
# After extensive experimentation with different model architectures, hyperparameters, and preprocessing techniques, researchers often find themselves unable to recreate their best-performing models because critical configuration details were not properly recorded.

# %% [markdown]
# ## MLflow
#
# [MLflow is an open-source platform](https://mlflow.org/) that addresses this challenge by providing systematic experiment tracking throughout the machine learning lifecycle. It automatically captures configurations, metrics, and artifacts from each model training run, transforming ad-hoc model development into a structured, reproducible process. In this notebook, we will learn how to use MLflow to properly track experiments for both traditional machine learning and deep learning workflows.

# %% [markdown]
# ### Learning objectives
#
# 1. **Implement automated experiment tracking** using MLflow autologging capabilities with scikit-learn, enabling automatic capture of model parameters and metrics without writing additional tracking code.
#
# 2. **Configure manual logging strategies** for PyTorch experiments, implementing custom tracking for metrics, parameters, and artifacts throughout the training process.
#
# 3. **Analyze and compare experimental results** using MLflow tracking UI and programmatic APIs to identify optimal model configurations and understand performance patterns.

# %% [markdown]
# ### Laboratory plan
#
# 1. **MLflow tracking server** configuration and deployment for experiment management
# 2. **Automatic logging mechanisms** for scikit-learn experiments
# 3. **Manual logging implementation** for PyTorch deep learning workflows
# 4. **Hyperparameter optimization exercise** - systematic hyperparameter exploration
# 5. **Best practices** for experiment organization, versioning, and cross-team reproducibility

# %% [markdown]
# ## 1. MLflow Tracking server configuration

# %% [markdown]
# [MLflow Tracking](https://mlflow.org/docs/latest/tracking/) is the main component of MLflow, responsible for capturing, storing, and presenting metrics, logs, and other tracking data. MLflow is based on a client-server architecture, where the central MLflow server can serve potentially whole teams of data scientists. You can also simply run it as a local server from the commandline, as we will now.

# %% [markdown]
# 1. Create a directory for MLflow artifacts storage:
# ```bash
# mkdir mlflow-artifacts
# ```
#
# 2. Start the MLflow tracking server:
# ```bash
# mlflow server \
#   --backend-store-uri sqlite:///mlflow.db \
#   --default-artifact-root ./mlflow-artifacts \
#   --host 0.0.0.0 \
#   --port 5000
# ```
# Important: Keep this terminal window open. The MLflow server will continue running and be accessible at http://localhost:5000

# %% [markdown]
# To verify if the server runs properly, let's connect to git:

# %%
import mlflow
import mlflow.sklearn

import warnings

warnings.filterwarnings("ignore")

mlflow.set_tracking_uri("http://localhost:5000")
print(f"Connected to MLflow at: {mlflow.get_tracking_uri()}")
# Out:
# Connected to MLflow at: http://localhost:5000

# %% [markdown]
# Setup complete! You now have the MLflow server running as a separate process, and `mlflow` library in this Jupyter Notebook is connected to it. Just note that we had to use the proper host and port - if you want to connect to a remote server, modify the tracking URI appropriately.

# %% [markdown]
# ## 2. Automatic logging with scikit-learn

# %% [markdown]
# ### 2.1 Dataset preparation
#
# In this section, we'll use the Ames Housing dataset to demonstrate MLflow's autologging capabilities with scikit-learn. Since we have already prepared the 2006-2008 data using DVC, we can use our preprocessed dataset here. As we have temporal data, the best way to evaluate our model is time (chronological) split, where the newest data is used for testing. We will assume that we have the data for years 2006 and 2007, and evaluate using data from 2008.

# %%
import numpy as np
import pandas as pd

from feature_engine.encoding import RareLabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# %%
df = pd.read_parquet("data/ames_data_2006_2008.parquet")

df = df.sort_values(by=["YrSold"])

df_train = df[df["YrSold"] < 2008]
df_test = df[df["YrSold"] == 2008]

y_train = df_train.pop("SalePrice")
y_test = df_test.pop("SalePrice")

categorical_features = df_train.select_dtypes(include="object").columns
numerical_features = df_train.select_dtypes(exclude="object").columns

# %%
median_imputer = SimpleImputer(strategy="median")
min_max_scaler = MinMaxScaler()
rare_encoder = RareLabelEncoder(tol=0.01, n_categories=0)
one_hot_encoder = OneHotEncoder(
    drop="first", sparse_output=False, handle_unknown="ignore"
)

num_pipeline = Pipeline(
    [("median_imputer", median_imputer), ("min_max_scaler", min_max_scaler)]
)

cat_pipeline = Pipeline(
    [("rare_encoder", rare_encoder), ("one_hot_encoder", one_hot_encoder)]
)

column_transformer = ColumnTransformer(
    [
        ("num_pipeline", num_pipeline, numerical_features),
        ("cat_pipeline", cat_pipeline, categorical_features),
    ],
    verbose_feature_names_out=False,
)
column_transformer.fit(df_train)

X_train = column_transformer.transform(df_train)
X_test = column_transformer.transform(df_test)
# Out:
# 2025/11/11 11:46:00 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '1798b16ace3d4e769f86376414ded53a', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2025/11/11 11:46:00 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 🏃 View run thundering-hare-787 at: http://localhost:5000/#/experiments/0/runs/1798b16ace3d4e769f86376414ded53a
# 🧪 View experiment at: http://localhost:5000/#/experiments/0
# 2025/11/11 11:46:01 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '20f15c56ef684fb2978022bcca4d6646', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2025/11/11 11:46:02 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 🏃 View run silent-croc-700 at: http://localhost:5000/#/experiments/0/runs/20f15c56ef684fb2978022bcca4d6646
# 🧪 View experiment at: http://localhost:5000/#/experiments/0

# %%
print(f"Training samples: {X_train.shape[0]}")
print(f"Test samples: {X_test.shape[0]}")
print(f"Number of features: {X_train.shape[1]}")
# Out:
# Training samples: 1312
# Test samples: 621
# Number of features: 181

# %% [markdown]
# ### 2.2 Training with MLflow autologging

# %% [markdown]
# Autologging is a powerful built-in capability of MLflow, enabling fully automated and near-zero code integration of MLflow with many popular frameworks. In particular, it works really well with scikit-learn, thanks to its highly unified API. Let's try this out - we will enable autologging, and then train a buch of different models.

# %%
mlflow.sklearn.autolog(
    log_input_examples=True, log_model_signatures=True, log_models=False, silent=False
)

mlflow.set_experiment("ames-housing-autolog")
# Out:
# 2025/11/11 11:46:10 WARNING mlflow.utils.autologging_utils: MLflow sklearn autologging is known to be compatible with 0.24.1 <= scikit-learn <= 1.6.1, but the installed version is 1.7.0. If you encounter errors during autologging, try upgrading / downgrading scikit-learn to a compatible version, or try upgrading MLflow.
# <Experiment: artifact_location='/home/ttzap/MlOps-course/lab/lab5/mlflow-artifacts/1', creation_time=1762782150279, experiment_id='1', last_update_time=1762782150279, lifecycle_stage='active', name='ames-housing-autolog', tags={}>

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor


models = [
    ("Ridge Regression", Ridge()),
    ("Decision Tree", DecisionTreeRegressor(max_depth=10, random_state=42)),
    ("K-Nearest Neighbors", KNeighborsRegressor(n_neighbors=10)),
    ("Random Forest", RandomForestRegressor(n_estimators=100, random_state=42)),
    ("Gradient Boosting", GradientBoostingRegressor(n_estimators=100, random_state=42)),
]

# %%
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score


def fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test):
    results = {}

    for model_name, model in models:
        # start MLflow run - a unit grouping logs from different model runs
        # everything within this context manager will get logged as a run
        with mlflow.start_run(run_name=model_name):
            model.fit(X_train, y_train)

            y_pred = model.predict(X_test)

            rmse = root_mean_squared_error(y_test, y_pred)
            mae = mean_absolute_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)

            cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring="r2")
            cv_mean = cv_scores.mean()
            cv_std = cv_scores.std()

            # log additional custom metrics, in addition to autologging
            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            results[model_name] = {
                "rmse": rmse,
                "mae": mae,
                "r2": r2,
                "cv_r2_mean": cv_mean,
            }

            print(f"\n{model_name}:")
            print(f"  RMSE: {rmse:.2f}")
            print(f"  MAE: {mae:.2f}")
            print(f"  R^2: {r2:.3f}")
            print(f"  CV R^2 (mean ± std): {cv_mean:.3f} ± {cv_std:.3f}")

# %%
fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test)
# Out:
# 2025/11/10 14:43:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:03 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:03 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:03 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:03 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:04 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:04 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Ridge Regression:
#   RMSE: 23450.39
#   MAE: 16430.79
#   R^2: 0.904
#   CV R^2 (mean ± std): 0.880 ± 0.037
# 🏃 View run Ridge Regression at: http://localhost:5000/#/experiments/1/runs/2282b806383d430492f49cc24332af05
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/11/10 14:43:04 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:04 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:04 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:05 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:05 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:05 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Decision Tree:
#   RMSE: 36860.51
#   MAE: 23270.66
#   R^2: 0.762
#   CV R^2 (mean ± std): 0.726 ± 0.080
# 🏃 View run Decision Tree at: http://localhost:5000/#/experiments/1/runs/6f6a781ca0b94e07b5aaff380520a074
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/11/10 14:43:05 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:06 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:06 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:06 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:06 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# K-Nearest Neighbors:
#   RMSE: 38325.06
#   MAE: 26034.07
#   R^2: 0.743
#   CV R^2 (mean ± std): 0.656 ± 0.050
# 🏃 View run K-Nearest Neighbors at: http://localhost:5000/#/experiments/1/runs/8d92a5299f514dd98943b8e96be1acf7
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/11/10 14:43:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:18 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:22 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:27 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:31 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Random Forest:
#   RMSE: 25896.23
#   MAE: 15509.71
#   R^2: 0.883
#   CV R^2 (mean ± std): 0.870 ± 0.043
# 🏃 View run Random Forest at: http://localhost:5000/#/experiments/1/runs/f606537c01d5455b94763b84188fff76
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/11/10 14:43:38 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:39 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:40 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:42 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 14:43:44 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Gradient Boosting:
#   RMSE: 21572.13
#   MAE: 13809.38
#   R^2: 0.919
#   CV R^2 (mean ± std): 0.898 ± 0.031
# 🏃 View run Gradient Boosting at: http://localhost:5000/#/experiments/1/runs/b2402cde56e447d7b361f2207c1aff3e
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %% [markdown]
# Open the MLflow dashboard at http://localhost:5000/ and go to the Experiments tab. On the left, you have the experiment name, and when you select it, the list of all experiments will show up. Click through the interface and familiarize yourself with the most important elements:
#
# 1. What columns can be selected
# 2. Pick a particular run and check what values are logged automatically
# 3. Select columns to compare a given metric between runs, e.g. MAE
# 4. Sort algorithms by the selected metric to pick the best one

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# We have trained 5 different models. The results of all of them can now be compared in MLflow. Since we obtained quite satisfactory results, our imaginary client would like to be sure that we do our best and wants us to compare many more combinations.
#
# Your task is to run 5 more experiments with different parameters and models from scikit-learn. You can use any [supervised learning methods from scikit-learn](https://scikit-learn.org/stable/supervised_learning.html). Find some other models or parameters to tune our current models with and run the experiments again. Use the function `fit_sklearn_models_with_cv()` created above, or you can write your own if you want.
#
# Did you manage to beat the previous approaches?

# %%
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import ElasticNet

models = [
    ("GBR (n_est=300, lr=0.05)", GradientBoostingRegressor(n_estimators=300, learning_rate=0.05, random_state=42)),
    ("GBR (max_depth=5)", GradientBoostingRegressor(n_estimators=100, max_depth=5, random_state=42)),

    ("Random Forest (n_est=300)", RandomForestRegressor(n_estimators=300, random_state=42)),
    ("Hist Gradient Boosting", HistGradientBoostingRegressor(random_state=42)),
    ("ElasticNet", ElasticNet(alpha=0.1, l1_ratio=0.5, random_state=42)),
]

fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test)
# Out:
# 2025/11/10 15:08:39 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:08:43 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:08:47 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:08:50 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:08:53 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:08:57 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:09:01 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# GBR (n_est=300, lr=0.05):
#   RMSE: 21073.45
#   MAE: 13406.86
#   R^2: 0.922
#   CV R^2 (mean ± std): 0.899 ± 0.030
# 🏃 View run GBR (n_est=300, lr=0.05) at: http://localhost:5000/#/experiments/1/runs/c9f6b04ab6d141a98aa34314327ef00b
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/11/10 15:09:04 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:09:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:09:09 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:09:10 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:09:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:09:15 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# GBR (max_depth=5):
#   RMSE: 22943.03
#   MAE: 13963.97
#   R^2: 0.908
#   CV R^2 (mean ± std): 0.888 ± 0.024
# 🏃 View run GBR (max_depth=5) at: http://localhost:5000/#/experiments/1/runs/7c07c22309264a0ebd345661dc07a73f
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/11/10 15:09:33 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:09:44 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:09:58 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:10:11 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:10:23 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:10:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Random Forest (n_est=300):
#   RMSE: 25597.46
#   MAE: 15386.09
#   R^2: 0.885
#   CV R^2 (mean ± std): 0.872 ± 0.040
# 🏃 View run Random Forest (n_est=300) at: http://localhost:5000/#/experiments/1/runs/4fd7d181aea149d3a26ec9e083b590d1
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/11/10 15:10:37 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:10:39 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:10:41 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:10:44 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:10:45 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:10:47 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Hist Gradient Boosting:
#   RMSE: 22857.71
#   MAE: 14258.98
#   R^2: 0.909
#   CV R^2 (mean ± std): 0.887 ± 0.031
# 🏃 View run Hist Gradient Boosting at: http://localhost:5000/#/experiments/1/runs/f96269cc49324c19b76b642b2fa47ff6
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/11/10 15:10:47 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:10:47 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:10:47 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:10:47 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/10 15:10:48 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# ElasticNet:
#   RMSE: 27319.47
#   MAE: 18594.52
#   R^2: 0.869
#   CV R^2 (mean ± std): 0.826 ± 0.031
# 🏃 View run ElasticNet at: http://localhost:5000/#/experiments/1/runs/8ef138d7ca274569a06dfbd070f5828a
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %% [markdown]
# Gradient Boosting with smaller lr and increasing the number of trees from 100 to 300 leading to better accuracy. More trees also help Random Forest make better predictions.

# %% [markdown]
# The best model according to the lowest RMSE is Gradient Boosting with learning rate = 0.05 and num_of_tree = 300

# %% [markdown]
# ## 3. Manual logging with PyTorch

# %% [markdown]
# In this section, we'll implement manual logging for PyTorch models. While scikit-learn has autologging, PyTorch requires manual tracking - giving us full control over what and when to log. MLflow supports autologging for [PyTorch Lightning](https://lightning.ai/docs/pytorch/stable/), but many people prefer or often need low-level control of pure PyTorch. Thus, we will focus on this approach, which also will teach us more about powerful MLflow capabilities.
#
# Note that we need to turn off scikit-learn autologging! Since we are using a Jupyter Notebook, MLflow uses the previously configured autologging unless explicitly turned off.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import KFold

# disable sklearn autologging!
mlflow.sklearn.autolog(disable=True)

mlflow.set_experiment("pytorch-housing-manual")
# Out:
# 2025/11/10 15:36:04 INFO mlflow.tracking.fluent: Experiment with name 'pytorch-housing-manual' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/home/ttzap/MlOps-course/lab/lab5/mlflow-artifacts/2', creation_time=1762785364112, experiment_id='2', last_update_time=1762785364112, lifecycle_stage='active', name='pytorch-housing-manual', tags={}>

# %% [markdown]
# ### 3.1 Targets transformation

# %% [markdown]
# Before training the neural network, we will transform the training target, in order to stabilize the training. To see why, let's plot the house prices:

# %%
y_train.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Training on such targets is possible, but very large target values easily risk overflow, particularly when a loss function like mean squared error is used. We will use the log-transform to transform this distribution, as it's near-exponential, so it should bring it closer to normal, and also greatly reduce the values range.
#
# Of course, we will need to transform the network predictions back again to evaluate them!

# %%
y_train_log = np.log1p(y_train)

pd.Series(y_train_log).plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### 3.2 Define and train the model

# %% [markdown]
# Since we have tabular data, we will use a simple 2-layer multilayer perceptron (MLP).

# %%
class HousePriceNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=128, dropout_rate=0.2):
        super(HousePriceNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# For training, we will check both the 5-fold CV performance, and the traditional train-test split. Cross-validation will give us an additional, robust performance estimation, as well as standard deviation, which is useful for comparing performances of different models. After all, if the difference between models would be within one standard deviation, it wouldn't really be meaningful.

# %%
import torch.nn as nn


class PyTorchTrainer:
    def __init__(self, model_class: type[nn.Module], config: dict):
        self.model_class = model_class
        self.config = config

    def create_model(self, input_dim: int) -> nn.Module:
        return self.model_class(
            input_dim=input_dim,
            hidden_dim=self.config["hidden_units"],
            dropout_rate=self.config["dropout"],
        )

    def create_data_loader(
        self, X: torch.Tensor, y: torch.Tensor, shuffle: bool = True
    ) -> DataLoader:
        dataset = TensorDataset(X, y)
        return DataLoader(
            dataset, batch_size=self.config["batch_size"], shuffle=shuffle
        )

    def train_epoch(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        criterion: nn.Module,
        optimizer: optim.Optimizer,
    ) -> float:
        model.train()
        epoch_loss = 0.0
        batch_count = 0

        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            batch_count += 1

        return epoch_loss / batch_count

    def train_model(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        epochs: int,
        metric_prefix: str = "",
    ) -> None:
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=self.config["learning_rate"])

        for epoch in range(epochs):
            avg_mse = self.train_epoch(model, train_loader, criterion, optimizer)

            if epoch % self.config["log_interval"] == 0:
                metric_name = (
                    f"{metric_prefix}train_mse" if metric_prefix else "train_mse"
                )
                # manually log metric value, with a given name and step value
                mlflow.log_metric(metric_name, avg_mse, step=epoch)

    @torch.no_grad()
    def evaluate_model(
        self,
        model: nn.Module,
        X: torch.Tensor,
        y_test: torch.Tensor,
        log_prefix: str = "",
    ) -> dict[str, float]:
        model.eval()

        y_pred_norm = model(X)

        # revert the logarithm with exponent
        y_pred = np.expm1(y_pred_norm.numpy())
        y_test = y_test.numpy()

        rmse = root_mean_squared_error(y_test.ravel(), y_pred.ravel())
        mae = mean_absolute_error(y_test.ravel(), y_pred.ravel())
        r2 = r2_score(y_test.ravel(), y_pred.ravel())

        if log_prefix:
            # manually log metrics that we want
            mlflow.log_metric(f"{log_prefix}_rmse", rmse)
            mlflow.log_metric(f"{log_prefix}_mae", mae)
            mlflow.log_metric(f"{log_prefix}_r2", r2)

        return {"rmse": rmse, "mae": mae, "r2": r2}

    def run_cross_validation(
        self, X_train: torch.Tensor, y_train: torch.Tensor, n_splits: int = 5
    ) -> tuple[float, float, list[float]]:
        kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
        cv_scores = []

        for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
            print(f"\nTraining Fold {fold + 1}/{n_splits}...")

            X_fold_train = X_train[train_idx]
            y_fold_train = y_train[train_idx]
            X_fold_val = X_train[val_idx]
            y_fold_val = y_train[val_idx]

            fold_model = self.create_model(X_train.shape[1])
            fold_loader = self.create_data_loader(X_fold_train, y_fold_train)

            self.train_model(
                fold_model,
                fold_loader,
                self.config["epochs"],
                metric_prefix=f"fold_{fold + 1}_",
            )

            # transform validation data with exponent back to original unit
            y_fold_val = np.expm1(y_fold_val)

            val_metrics = self.evaluate_model(
                fold_model, X_fold_val, y_fold_val, log_prefix=f"fold_{fold + 1}_val"
            )

            cv_scores.append(val_metrics["r2"])
            print(
                f"  Fold {fold + 1} "
                f"Validation - RMSE: {val_metrics['rmse']:.2f}, "
                f"MAE: {val_metrics['mae']:.2f} "
                f"R^2: {val_metrics['r2']:.3f}"
            )

        return np.mean(cv_scores), np.std(cv_scores), cv_scores

    def fit(
        self,
        X_train: pd.DataFrame | np.ndarray,
        y_train: pd.Series | np.ndarray,
        X_test: pd.DataFrame | np.ndarray,
        y_test: pd.Series | np.ndarray,
    ) -> dict:
        X_train, X_test, y_train, y_test = self._prepare_tensors(
            X_train, X_test, y_train, y_test
        )

        with mlflow.start_run(run_name=self.config["name"]):
            mlflow.log_params(self.config)

            print(f"Starting 5-fold cross-validation for {self.config['name']}...")
            cv_mean, cv_std, cv_scores = self.run_cross_validation(X_train, y_train)

            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            print(
                f"\nCross-validation complete. Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})"
            )
            print("\nTraining final model on all training data...")

            final_model = self.create_model(X_train.shape[1])
            final_loader = self.create_data_loader(X_train, y_train)

            self.train_model(
                final_model,
                final_loader,
                self.config["epochs"],
                metric_prefix="final_model_",
            )

            print("\nEvaluating on test set...")
            test_metrics = self.evaluate_model(final_model, X_test, y_test)

            mlflow.log_metric("test_rmse", test_metrics["rmse"])
            mlflow.log_metric("test_mae", test_metrics["mae"])
            mlflow.log_metric("test_r2", test_metrics["r2"])

            self._print_results(test_metrics, cv_mean, cv_std)

            return {
                "rmse": test_metrics["rmse"],
                "mae": test_metrics["mae"],
                "r2": test_metrics["r2"],
                "cv_r2_mean": cv_mean,
                "cv_r2_std": cv_std,
                "cv_scores": cv_scores,
            }

    def _prepare_tensors(self, X_train, X_test, y_train, y_test) -> tuple:
        y_train = np.array(y_train)
        y_test = np.array(y_test)

        X_train_tensor = torch.FloatTensor(X_train)
        y_train_tensor = torch.FloatTensor(y_train.reshape(-1, 1))

        X_test_tensor = torch.FloatTensor(X_test)
        y_test_tensor = torch.FloatTensor(y_test.reshape(-1, 1))

        print(f"Training samples: {X_train_tensor.shape[0]}")
        print(f"Input features: {X_train_tensor.shape[1]}")

        return X_train_tensor, X_test_tensor, y_train_tensor, y_test_tensor

    def _print_results(
        self, test_metrics: dict[str, float], cv_mean: float, cv_std: float
    ) -> None:
        print(f"{'=' * 50}\n")
        print(f"  Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})")
        print("\nCross-Validation Performance:")
        print(f"  R^2: {test_metrics['r2']:.3f}")
        print(f"  RMSE: {test_metrics['rmse']:.2f}")
        print(f"  MAE: {test_metrics['mae']:.2f}")
        print("Test Set Performance:")
        print(f"{'=' * 50}")
        print(f"FINAL RESULTS for {self.config['name']}:")
        print(f"\n{'=' * 50}")

# %% [markdown]
# Quite a bit of code there! So now let's train the model.

# %%
base_config = {
    "model_class": HousePriceNet,
    "random_seed": 42,
    "log_interval": 5,
    "num_samples": X_train.shape[0],
    "input_features": X_train.shape[1],
    "k_folds": 5,
}

config = {
    "name": "first_run",
    "hidden_units": 128,
    "dropout": 0.1,
    "learning_rate": 0.03,
    "epochs": 150,
    "batch_size": 32,
}

# %%
training_config = base_config | config

trainer = PyTorchTrainer(training_config["model_class"], training_config)
results = trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for first_run...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 23504.90, MAE: 16546.39 R^2: 0.910
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 50418.69, MAE: 43659.00 R^2: 0.570
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 38315.65, MAE: 26432.29 R^2: 0.793
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 32704.88, MAE: 22520.36 R^2: 0.823
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 75815.10, MAE: 61873.61 R^2: 0.107
#
# Cross-validation complete. Mean R^2: 0.641 (+/- 0.290)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.641 (+/- 0.290)
#
# Cross-Validation Performance:
#   R^2: 0.880
#   RMSE: 26222.97
#   MAE: 18100.97
# Test Set Performance:
# ==================================================
# FINAL RESULTS for first_run:
#
# ==================================================
# 🏃 View run first_run at: http://localhost:5000/#/experiments/2/runs/08ec7356847d4559accd9c95e1a3a57b
# 🧪 View experiment at: http://localhost:5000/#/experiments/2

# %% [markdown]
# Go to the MLflow dashboard and take a look at logged values. Focus particularly on the "Model metrics" tab, which for neural networks visualizes the progress of iterative training.

# %% [markdown]
# ### 3.3 Hyperparameter optimization with MLflow

# %% [markdown]
# Now, we will use MLflow logging and visualization capabilities to help us tune hyperparameters of neural networks. This is one of the major applications of experiment tracking frameworks. As neural networks have many hyperparameters, with complex interactions, and training them many times is very computationally intensive, we want to use human judgment, based on plots and metrics, to guide our choices in further experiments.
#
# A quick recap on main hyperparameters of MLPs:
#
# 1. **Learning rate:**
#    - typically 1e-5 to 1e-1
#    - too high: loss explodes, model diverges
#    - too low: slow convergence, might get stuck
#    - sweet spot: fast convergence to good minimum
#
# 3. **Model size** - number of hidden units here:
#    - typically 32 to 512
#    - too few: underfitting, can't capture patterns
#    - too many: overfitting, slow training, diminishing returns
#    - consider: more features need more capacity
#
# 5. **Dropout rate:**
#    - typically 0.0 to 0.5
#    - 0.0: no regularization, risk overfitting
#    - too high: underfitting, loses important information
#    - purpose: prevents over-reliance on specific neurons
#
# 7. **Batch size:**
#    - typically 16 to 128
#    - small: noisy gradients, often better generalization, slower
#    - large: stable gradients, faster training, needs more memory, may overfit
#    - trade-off: speed vs generalization
#
# 9. **Number of epochs:**
#    - too few: underfitting
#    - too many: overfitting
#    - optimal: when validation loss stops improving
#    - watch validation loss

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Your task is to:
# 1. Run 10 experiments by modifying the hyperparameter configuration. Try to improve model performance, which is currently overfitted.
# 2. Analyze results in MLflow UI.
# 3. Comment on what changes impacted the model performance the most, and what changes disrupted the training process.
# 4. Compare the results of our first scikit-learn configuration with the first PyTorch experiments. Do you see any overfitting in the first PyTorch experiment? Explain what signs of overfitting can indicate this situation.
#
# Example:
#
# ```python
#
# base_config = {
#     # or any other your own architecture :) we definitely recommend to experiment by yourselves
#     "model_class": HousePriceNet,
#     "random_seed": 42,
#     "log_interval": 5,
#     "input_features": X_train.shape[1],
#     "num_samples": X_train.shape[0],
#     "target_normalized": True,
#     "k_folds": 5,
# }
#
# configs = {
#      {
#         "name": "first_run_or_other_your_own_meaningful_name",
#         "hidden_units": 128,
#          ...
#      },
#     {
#         "name": "second_run_or...",
#         "hidden_units": 128,
#         "dropout": 0.1,
#         "learning_rate": 0.03,
#         "epochs": 150,
#         "batch_size": 32,
#     }
# }
#
# for config in configs:
#     # in python we can in elegant way merge two dicts using "|" operator - finally...
#     # old merging method {**base_config, **config} - ugly :(
#     training_config = base_config | config
#     trainer = PyTorchTrainer(training_config["model_class"], preprocessor, training_config)
#     results = trainer.fit(X_train, y_train, X_test, y_test)
# ```
#
# or just manually and incrementally:
#
# ```python
# new_config = {
#     "name": "second_run_or...",
#     "hidden_units": 128,
#     "dropout": 0.1,
#     "learning_rate": 0.03,
#     "epochs": 150,
#     "batch_size": 32,
# }
#
# training_config = base_config | config
# trainer = PyTorchTrainer(training_config["model_class"], preprocessor, training_config)
# results = trainer.fit(X_train, y_train, X_test, y_test)
# ```

# %%
configs = [
    {
        "name": "Baseline",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.05,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "LR_0.01",Architektura (Hidden Units): Model ze 128 ukrytymi jednostkami (użyty w obu najlepszych przebiegach) wydaje się na ten moment najlepszy. Mniejszy model (Smaller, 64 jednostki) był gorszy, a szerszy (Wider, 256 jednostek) również nie wypadł dobrze, choć był testowany tylko z mniej optymalnymi wartościami lr (0.05 i 0.001).
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.01,
        "epochs": 100,
        "batch_size": 32,
    },
    {
        "name": "LowLR_MoreEpochs",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.001,
        "epochs": 300,
        "batch_size": 32,
    },
    {
        "name": "Wider",
        "hidden_units": 256,
        "dropout": 0.1,
        "learning_rate": 0.05,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "Smaller",
        "hidden_units": 64,
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "Reg_HighDropout_0.3",
        "hidden_units": 128,
        "dropout": 0.3,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "NoDropout_0.0",
        "hidden_units": 128,
        "dropout": 0.0,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "BatchSize_Large_64",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 64,
    },
    {
        "name": "BatchSize_Small_16",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 16,
    },
    {
        "name": "Wider_LowLR_HighDropout",
        "hidden_units": 256,
        "dropout": 0.5,
        "learning_rate": 0.001,
        "epochs": 300,
        "batch_size": 32,
    },
]


for config in configs:
    training_config = base_config | config
    trainer = PyTorchTrainer(training_config["model_class"], training_config)
    results = trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for Baseline...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 23578.38, MAE: 17281.69 R^2: 0.910
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 25724.51, MAE: 18007.18 R^2: 0.888
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 21853.42, MAE: 15474.69 R^2: 0.933
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 27376.05, MAE: 18347.98 R^2: 0.876
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 32463.53, MAE: 22131.54 R^2: 0.836
#
# Cross-validation complete. Mean R^2: 0.889 (+/- 0.033)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.889 (+/- 0.033)
#
# Cross-Validation Performance:
#   R^2: 0.800
#   RMSE: 33803.22
#   MAE: 24520.33
# Test Set Performance:
# ==================================================
# FINAL RESULTS for Baseline:
#
# ==================================================
# 🏃 View run Baseline at: http://localhost:5000/#/experiments/2/runs/e59782dfe5544879b42b0796e96a26b0
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for LR_0.01...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 58870.51, MAE: 38690.24 R^2: 0.437
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 45562.52, MAE: 32316.14 R^2: 0.649
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 88300.88, MAE: 75853.84 R^2: -0.100
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 45539.80, MAE: 33071.14 R^2: 0.657
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 53585.00, MAE: 36517.91 R^2: 0.554
#
# Cross-validation complete. Mean R^2: 0.439 (+/- 0.281)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.439 (+/- 0.281)
#
# Cross-Validation Performance:
#   R^2: 0.569
#   RMSE: 49601.38
#   MAE: 40271.53
# Test Set Performance:
# ==================================================
# FINAL RESULTS for LR_0.01:
#
# ==================================================
# 🏃 View run LR_0.01 at: http://localhost:5000/#/experiments/2/runs/c5511d833b7145e5add90f39ccf6b9f0
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for LowLR_MoreEpochs...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 61855.03, MAE: 32587.89 R^2: 0.379
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 44593.29, MAE: 30707.94 R^2: 0.664
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 47155.30, MAE: 33591.56 R^2: 0.686
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 46116.37, MAE: 35496.16 R^2: 0.648
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 49178.29, MAE: 36339.14 R^2: 0.624
#
# Cross-validation complete. Mean R^2: 0.600 (+/- 0.113)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.600 (+/- 0.113)
#
# Cross-Validation Performance:
#   R^2: 0.701
#   RMSE: 41343.87
#   MAE: 28365.60
# Test Set Performance:
# ==================================================
# FINAL RESULTS for LowLR_MoreEpochs:
#
# ==================================================
# 🏃 View run LowLR_MoreEpochs at: http://localhost:5000/#/experiments/2/runs/da4f52257b4148e5842f510caa10e242
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for Wider...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 24523.01, MAE: 18382.53 R^2: 0.902
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 24363.34, MAE: 17167.74 R^2: 0.900
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 20454.39, MAE: 14334.86 R^2: 0.941
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 25702.40, MAE: 17063.84 R^2: 0.891
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 27655.43, MAE: 17435.35 R^2: 0.881
#
# Cross-validation complete. Mean R^2: 0.903 (+/- 0.020)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.903 (+/- 0.020)
#
# Cross-Validation Performance:
#   R^2: 0.774
#   RMSE: 35906.72
#   MAE: 26385.03
# Test Set Performance:
# ==================================================
# FINAL RESULTS for Wider:
#
# ==================================================
# 🏃 View run Wider at: http://localhost:5000/#/experiments/2/runs/143f92353f974a8e80f78ca770dfe4d7
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for Smaller...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 21129.41, MAE: 15147.00 R^2: 0.927
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 20513.10, MAE: 14625.02 R^2: 0.929
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 19787.26, MAE: 14184.92 R^2: 0.945
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 31411.90, MAE: 23323.03 R^2: 0.837
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 23608.71, MAE: 15237.69 R^2: 0.913
#
# Cross-validation complete. Mean R^2: 0.910 (+/- 0.038)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.910 (+/- 0.038)
#
# Cross-Validation Performance:
#   R^2: 0.839
#   RMSE: 30360.14
#   MAE: 21860.89
# Test Set Performance:
# ==================================================
# FINAL RESULTS for Smaller:
#
# ==================================================
# 🏃 View run Smaller at: http://localhost:5000/#/experiments/2/runs/e770f8768de04e6f965fca901820ba51
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for Reg_HighDropout_0.3...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 27141.01, MAE: 18883.57 R^2: 0.880
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 27904.00, MAE: 19870.17 R^2: 0.868
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 22419.06, MAE: 15448.47 R^2: 0.929
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 24548.67, MAE: 17034.96 R^2: 0.900
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 26190.97, MAE: 16710.43 R^2: 0.893
#
# Cross-validation complete. Mean R^2: 0.894 (+/- 0.021)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.894 (+/- 0.021)
#
# Cross-Validation Performance:
#   R^2: 0.889
#   RMSE: 25158.80
#   MAE: 17091.96
# Test Set Performance:
# ==================================================
# FINAL RESULTS for Reg_HighDropout_0.3:
#
# ==================================================
# 🏃 View run Reg_HighDropout_0.3 at: http://localhost:5000/#/experiments/2/runs/a2bef9187fec48298c5c2e8bde373f2b
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for NoDropout_0.0...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 47690.52, MAE: 27436.65 R^2: 0.631
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 42303.48, MAE: 27357.96 R^2: 0.697
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 37915.93, MAE: 28607.04 R^2: 0.797
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 47382.22, MAE: 38158.82 R^2: 0.628
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 41659.70, MAE: 30354.57 R^2: 0.730
#
# Cross-validation complete. Mean R^2: 0.697 (+/- 0.064)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.697 (+/- 0.064)
#
# Cross-Validation Performance:
#   R^2: 0.691
#   RMSE: 41991.08
#   MAE: 29796.24
# Test Set Performance:
# ==================================================
# FINAL RESULTS for NoDropout_0.0:
#
# ==================================================
# 🏃 View run NoDropout_0.0 at: http://localhost:5000/#/experiments/2/runs/e591faf803f145738cb6b61625eb667d
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for BatchSize_Large_64...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 49319.79, MAE: 39023.52 R^2: 0.605
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 85854.80, MAE: 67578.55 R^2: -0.247
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 100757.08, MAE: 79957.22 R^2: -0.432
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 41207.89, MAE: 30483.04 R^2: 0.719
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 54396.56, MAE: 37901.15 R^2: 0.540
#
# Cross-validation complete. Mean R^2: 0.237 (+/- 0.478)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.237 (+/- 0.478)
#
# Cross-Validation Performance:
#   R^2: 0.185
#   RMSE: 68243.55
#   MAE: 54983.79
# Test Set Performance:
# ==================================================
# FINAL RESULTS for BatchSize_Large_64:
#
# ==================================================
# 🏃 View run BatchSize_Large_64 at: http://localhost:5000/#/experiments/2/runs/9c918c1f521c469da9f52db8ff1beaed
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for BatchSize_Small_16...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 37277.29, MAE: 25455.49 R^2: 0.774
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 86252.46, MAE: 50625.17 R^2: -0.258
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 31552.02, MAE: 24581.98 R^2: 0.860
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 32453.92, MAE: 19920.64 R^2: 0.826
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 46608.93, MAE: 34311.62 R^2: 0.662
#
# Cross-validation complete. Mean R^2: 0.573 (+/- 0.421)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.573 (+/- 0.421)
#
# Cross-Validation Performance:
#   R^2: 0.886
#   RMSE: 25506.33
#   MAE: 17750.70
# Test Set Performance:
# ==================================================
# FINAL RESULTS for BatchSize_Small_16:
#
# ==================================================
# 🏃 View run BatchSize_Small_16 at: http://localhost:5000/#/experiments/2/runs/e08951d96ec14260ac4af1d46aca61bc
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for Wider_LowLR_HighDropout...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 59911.46, MAE: 32733.61 R^2: 0.417
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 44317.75, MAE: 32153.73 R^2: 0.668
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 41360.85, MAE: 29402.58 R^2: 0.759
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 63330.95, MAE: 44449.75 R^2: 0.336
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 40991.22, MAE: 30723.13 R^2: 0.739
#
# Cross-validation complete. Mean R^2: 0.584 (+/- 0.174)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.584 (+/- 0.174)
#
# Cross-Validation Performance:
#   R^2: 0.559
#   RMSE: 50191.42
#   MAE: 37041.94
# Test Set Performance:
# ==================================================
# FINAL RESULTS for Wider_LowLR_HighDropout:
#
# ==================================================
# 🏃 View run Wider_LowLR_HighDropout at: http://localhost:5000/#/experiments/2/runs/0a57c426c2d546dabcdcc5cf91aa6556
# 🧪 View experiment at: http://localhost:5000/#/experiments/2

# %% [markdown]
# ### Lab assessment
#
# Fill the code exercises in this Jupyter notebook, and send it with completed exercises, written comments in Markdown cells (particularly for questions in exercise 2), and screenshots of results in MLflow.

# %% [markdown]
# Higher batch size lead to the worse result. Combined with lr = 0.3, the optimizer could jump over global minimum result in instability and really poor convergence. Without dropout model perfectly learned whole training dataset, but when it came to predicting test data it performed quite poorly. It also worth to notice that decreasing lr and increasing number of epochs didn't helped. Training was disrupted by getting stuck in a weak minimum from which the model could not get out. Increasing dropout from 0.1 to 0.3 and decreasing batch size helped the most in terms of RMSE. A higher dropout rate helped with generalization while a smaller batch size introduced more stochasticity, making it harder for the model to overfit.

# %% [markdown]
# In our first pytorch experiment we can notice some signs of overfitting. These include:
# - The R² scores are not stable. The score changes a lot, from 0.91 (which is great) in one fold, down to 0.57 and even 0.11 (which is very bad). This shows the model's performance is random and depends too much on the data it was trained on.
#
# - The "cv_r2_std" is very high. This number confirms what we see in point 1: the model is just not reliable.
#
# - There is a big gap between the low training MSE (0.029) and the high test RMSE (26,222). This is a classic sign of overfitting. It means the model learned the training data too perfectly (memorized it) but did not learn the real pattern, so it failed on the test data.

# %% [markdown]
# ![image.png](attachment:ff6c2216-4ebb-4131-8522-beddd7a84e8d.png)

# %% [markdown]
# ![image.png](attachment:69c71f21-bee1-4e52-bc64-18212004cd51.png)
